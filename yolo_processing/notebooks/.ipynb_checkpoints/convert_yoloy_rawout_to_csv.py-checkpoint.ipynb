# %%
import os 
import sys
os.chdir(r'E:\Research-WeiZhou\darknet\build\darknet\x64\results')
file_name = 'SH09_TTexp1_full_behavCam.txt'
file = open(file_name)
raw_string = file.read()

# %%
frame_strings = raw_string.split('\n\n')
keep = ['left:', 'right:', 'top', 'midpoint', 'frame_num:']
lines = [ line for frame_string in frame_strings for line in frame_string.split('\n') if line.split(' ')[0] in keep ]

# %%
raw_nums = []
temp = []
temp.append(int(lines[0].split(':')[1]))
for line in lines[1:]:
    line_split = line[:-1].split(':')
    if line_split[0] != 'frame_num':
        temp.append(int(line_split[1]))
    else:
        raw_nums.append(temp)
        temp =[(int(line_split[1]))]
raw_nums.append(temp)       
raw_nums[-5:]
# Out:
# [[25063, 91, 554, 65, 495, 83],
#  [25064, 91, 553, 65, 495, 83],
#  [25065, 91, 553, 65, 495, 83],
#  [25066, 91, 553, 65, 495, 83],
#  [25067, 91, 553, 65, 494, 83]]

# %%
save = []
count_same_box = 0
for idx, line in enumerate(raw_nums):
    if len(line) == 11: 
        if (abs(line[2] - line[7]) < 30 ):
            print(line)
    if len(line) > 11:
        #print(line)
        save.append((idx, raw_nums[idx]))
# Out:
# [7113, 58, 352, 61, 301, 80, 79, 350, 63, 303, 83]
# [7114, 62, 352, 61, 300, 80, 78, 349, 62, 302, 82]
# [7115, 63, 352, 61, 301, 80, 78, 349, 62, 302, 82]
# [7116, 64, 351, 61, 300, 80, 78, 349, 62, 302, 82]
# [7117, 66, 351, 61, 300, 80, 78, 349, 62, 302, 82]
# [7118, 66, 351, 61, 300, 80, 78, 349, 62, 302, 82]
# [7119, 65, 352, 61, 301, 80, 78, 349, 62, 302, 82]
# [7120, 60, 352, 61, 301, 80, 79, 349, 62, 302, 82]
# [7122, 59, 352, 61, 301, 80, 79, 349, 62, 302, 82]
# [7123, 64, 353, 61, 301, 80, 79, 350, 62, 303, 82]
# [7184, 66, 342, 60, 287, 78, 65, 348, 59, 295, 78]
# [7185, 65, 343, 60, 287, 78, 62, 348, 60, 295, 78]
# [7205, 73, 335, 60, 286, 78, 55, 340, 59, 294, 78]
# [7222, 65, 258, 61, 199, 80, 58, 253, 63, 199, 83]
# [19091, 56, 92, 66, 45, 85, 67, 100, 64, 53, 83]
# [21907, 68, 494, 67, 434, 84, 62, 497, 66, 441, 83]
# [21908, 62, 494, 67, 434, 83, 69, 496, 66, 441, 82]
# [21952, 57, 528, 61, 478, 80, 69, 532, 66, 480, 83]
# [21953, 64, 527, 61, 477, 79, 60, 531, 66, 480, 83]
# [21955, 60, 528, 61, 478, 80, 58, 532, 66, 481, 83]
# [21960, 57, 538, 66, 483, 83, 76, 544, 65, 490, 82]
# [21961, 56, 539, 66, 483, 83, 74, 544, 65, 490, 83]
# [21964, 61, 538, 66, 483, 83, 59, 545, 65, 490, 83]
# [22008, 75, 537, 65, 483, 83, 58, 545, 65, 490, 83]
# [22009, 74, 537, 65, 483, 83, 65, 545, 65, 490, 83]
# [22010, 74, 537, 65, 483, 83, 65, 545, 65, 490, 83]
# [22011, 75, 537, 65, 483, 83, 59, 545, 65, 490, 83]
# [22055, 64, 536, 65, 483, 82, 55, 544, 65, 489, 83]
# [22124, 58, 531, 61, 480, 80, 67, 543, 65, 490, 83]

# %%
for idx, line in enumerate(raw_nums):
    if len(line) > 16:
        x1 = line[1]
        x2 = line[6]
        x3 = line[11]
        x4 = line[16]
        smallest = min(x1, x2, x3, x4)
        if x1 == small:
            line = [line[0]] + line[6:]
        elif x2 == small:
            line = line[0:6] + line[11:]
        elif x3 == small:
            line = line[0:11] + line[16:]
        else:
            line = line[0:16]
    
    if len(line) > 11:
        x1 = line[1]
        x2 = line[6]
        x3 = line[11]
        small = min (x1, x2, x3)
        if x1 == small:
            if (abs(line[12] - line[7]) < 30 ):
                line = line[0:6] + line[11:]
            else:
                line = [line[0]] + line[6:]
        elif x2 == small:
            if (abs(line[2] - line[12]) < 30 ):
                line = [line[0]] + line[6:]
            else:
                line = line[0:6] + line[11:]
        else:
            if (abs(line[2] - line[7]) < 30 ):
                line = line[0:6] + line[11:]
            else:
                line = line[0:11]
    if len(line) > 6:
        line = [line[0]] + line[2:6] + line[7:]
        if len(line) == 9 and line[1] > line[5]:
            line = [line[0]] + line[5:] + line[1:5]            
        #fix xcord to be from right to left
        line[1] = 2*line[3] - line[1]
        line[5] = 2*line[7] - line[5]
    elif len(line) > 1:
        line = [line[0]] + line[2:]
        #fix xcord to be from right to left
        line[1] = 2*line[3] - line[1]

    else:
        pass
    raw_nums[idx] = line

# %%
for i in save:
    if(abs(raw_nums[i[0]][1] - raw_nums[i[0]][5]) < 30):
        print(raw_nums[i[0]])
        print(i[1])



count_one_box = 0
count_zero_box = 0
count_ten_consec = 0
num_consec = 0
consec_frames = []
for idx, line in enumerate(raw_nums):
        
    if len(line) == 5:
        count_one_box = count_one_box + 1
        num_consec = num_consec + 1
    elif len(line) == 1:
        count_zero_box = count_zero_box + 1
        num_consec = num_consec + 1
    elif len(line) == 9: 
        if (abs(line[1] - line[5]) < 30 ):
            count_one_box = count_one_box+1
            raw_nums[idx] = line[:5]
        num_consec = 0
    else:
        print("entered")
        num_consec = 0
    
    if num_consec >= 10:
        count_ten_consec = count_ten_consec + 1
        consec_frames.append(line[0])
num_frames = len(raw_nums)
count_one_box_percent = 100*(count_one_box / float(num_frames))
count_zero_box_percent = 100*(count_zero_box / float(num_frames))
count_ten_consec_percent =100*(count_ten_consec / float(num_frames))

name = file_name.split('.')[0]
string = "File: {} \nNumFrames: {}\nCountOneBox: {}\nCountZeroBox: {}\nCountTenConsec: {}\nPercentOneBox: {}\nPercentZeroBox: {}\nPercentTenConsec: {}\n\n".format(name, num_frames, count_one_box, count_zero_box, count_ten_consec, count_one_box_percent, count_zero_box_percent, count_ten_consec_percent)
string
# Out:
# 'File: SH11_TTexp1_full_behavCam \nNumFrames: 26310\nCountOneBox: 2150\nCountZeroBox: 187\nCountTenConsec: 945\nPercentOneBox: 8.171797795515014\nPercentTenBox: 0.7107563664006081\nPercentTenConsec: 3.5917901938426455\n\n'

# %%
stats_file = open("stats.txt", "a")
stats_file.write(string)
stats_file.close()
stats_file = open

# %%
import csv
new_file_name = "result_{}.csv".format(file_name.split('.')[0])
new_file = open(new_file_name, 'w')
fieldnames = ['frame_num', 'top_x1', 'top_y1', 'mid_x1', 'mid_y1', 'top_x2', 'top_y2', 'mid_x2', 'mid_y2' ]
csv_writer = csv.writer(new_file)
csv_writer.writerow(fieldnames)
for row in raw_nums:
    csv_writer.writerow(row)
new_file.close()

# %%
import pandas as pd
    
pd.read_csv(new_file_name)
# Out:
#        frame_num  top_x1  top_y1  mid_x1  mid_y1  top_x2  top_y2  mid_x2  \
# 0              2     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1              3     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2              4     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3              5     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4              6     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5              7     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6              8     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7              9     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8             10     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9             11     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10            12     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 11            13     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 12            14     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 13            15     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 14            16     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 15            17     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 16            18     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 17            19     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 18            20     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 19            21     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 20            22     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 21            23     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 22            24     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 23            25   160.0    51.0   221.0    70.0     NaN     NaN     NaN
# 24            26   161.0    51.0   223.0    70.0     NaN     NaN     NaN
# 25            27     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 26            28     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 27            29     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 28            30     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 29            31     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...          ...     ...     ...     ...     ...     ...     ...     ...
# 26280      26282   477.0    47.0   519.0    64.0   559.0    47.0   591.0
# 26281      26283   559.0    47.0   591.0    67.0     NaN     NaN     NaN
# 26282      26284   475.0    48.0   521.0    66.0   558.0    47.0   591.0
# 26283      26285   558.0    47.0   591.0    67.0     NaN     NaN     NaN
# 26284      26286   558.0    47.0   591.0    67.0     NaN     NaN     NaN
# 26285      26287   558.0    47.0   591.0    67.0     NaN     NaN     NaN
# 26286      26288   558.0    47.0   591.0    67.0     NaN     NaN     NaN
# 26287      26289   558.0    47.0   591.0    67.0     NaN     NaN     NaN
# 26288      26290   558.0    47.0   591.0    67.0     NaN     NaN     NaN
# 26289      26291   476.0    47.0   521.0    65.0   558.0    47.0   591.0
# 26290      26292   476.0    47.0   521.0    65.0   558.0    47.0   591.0
# 26291      26293   476.0    47.0   521.0    65.0   558.0    47.0   591.0
# 26292      26294   558.0    47.0   591.0    67.0     NaN     NaN     NaN
# 26293      26295   558.0    47.0   591.0    67.0     NaN     NaN     NaN
# 26294      26296   476.0    48.0   521.0    65.0   560.0    47.0   592.0
# 26295      26297   477.0    48.0   522.0    65.0     NaN     NaN     NaN
# 26296      26298   477.0    48.0   522.0    65.0     NaN     NaN     NaN
# 26297      26299   477.0    48.0   522.0    65.0   559.0    47.0   592.0
# 26298      26300   477.0    47.0   522.0    65.0   560.0    47.0   592.0
# 26299      26301   477.0    47.0   522.0    65.0   560.0    47.0   592.0
# 26300      26302   476.0    47.0   522.0    65.0   560.0    47.0   592.0
# 26301      26303   476.0    47.0   522.0    65.0   561.0    47.0   593.0
# 26302      26304   476.0    48.0   522.0    66.0   561.0    47.0   593.0
# 26303      26305   475.0    47.0   521.0    65.0   561.0    47.0   593.0
# 26304      26306   477.0    48.0   522.0    65.0   560.0    47.0   592.0
# 26305      26307   476.0    48.0   521.0    65.0   560.0    47.0   592.0
# 26306      26308   478.0    48.0   522.0    65.0   561.0    47.0   592.0
# 26307      26309   478.0    48.0   522.0    65.0   561.0    47.0   592.0
# 26308      26310   477.0    48.0   522.0    65.0   561.0    47.0   592.0
# 26309      26311   476.0    48.0   521.0    65.0   560.0    47.0   592.0
#
#        mid_y2
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# ...       ...
# 26280    67.0
# 26281     NaN
# 26282    67.0
# 26283     NaN
# 26284     NaN
# 26285     NaN
# 26286     NaN
# 26287     NaN
# 26288     NaN
# 26289    67.0
# 26290    67.0
# 26291    67.0
# 26292     NaN
# 26293     NaN
# 26294    67.0
# 26295     NaN
# 26296     NaN
# 26297    67.0
# 26298    67.0
# 26299    67.0
# 26300    67.0
# 26301    67.0
# 26302    67.0
# 26303    67.0
# 26304    67.0
# 26305    67.0
# 26306    67.0
# 26307    67.0
# 26308    67.0
# 26309    67.0
#
# [26310 rows x 9 columns]

# %%
import cv2
from matplotlib import pyplot as plt
import matplotlib.patches as patches
def showimg (frame_num, x, y, mx, my):
    width = 2 * (mx - x)
    height = 2 * (my - y)
    nx = x 
    ny = y
    cap = cv2.VideoCapture(r'E:\Research-WeiZhou\darknet\build\darknet\x64\results\result_{}.avi'.format(file_name.split('.')[0]))
    for i in range(0, frame_num) :
        ret, frame = cap.read()
    print(cap.get(cv2.CAP_PROP_POS_FRAMES))
    fig, ax = plt.subplots(1)
    ax.imshow(frame)
    rect = patches.Rectangle((nx, ny), width, height,linewidth=2,edgecolor='r',facecolor='none')
    ax.add_patch(rect)
    plt.show()

    
showimg(785, 376, 11, 419, 35)
# Out:
# 785.0
